# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append('../utils/')
from spectra_pretreatment import get_flux_data, flux_transform

# %%
test_label = pd.read_csv("../data/refer_set/test_label.csv")
flux_raw = get_flux_data(path="../data/other_data/", valid_data=test_label.iloc[:5])
flux_normal = flux_transform(flux_raw)
# Out:
# reading: 100%|██████████| 5/5 [00:00<00:00, 17.51it/s]

# %%
B_wavelength_fixed = np.arange(4968, 5328, 0.1)
R_wavelength_fixed = np.arange(6339, 6699, 0.1)

plt.figure(figsize=(12,4),dpi=180)

plt.subplot(2,2,1)
plt.plot(B_wavelength_fixed, flux_raw[0,:3600], 'k')
plt.ylabel("Relative Flux", size=14)
plt.subplot(2,2,2)
plt.plot(R_wavelength_fixed, flux_raw[0,3600:], 'k')


plt.subplot(2,2,3)
plt.plot(B_wavelength_fixed, flux_normal[0,:3600], 'k')
plt.ylabel("Normalized Flux", size=14)
plt.xlabel("Wavelength_blue", size=14)

plt.subplot(2,2,4)
plt.plot(R_wavelength_fixed, flux_normal[0,3600:], 'k')
plt.xlabel("Wavelength_red", size=14)


plt.tight_layout()
plt.show()
